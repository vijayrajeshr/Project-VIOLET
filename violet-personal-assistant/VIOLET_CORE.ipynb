# %% [markdown]
# # VIOLET CORE
# Welcome to the main control hub for the VIOLET Assistant.

# %%
from core.brain import Brain
from core.ears import Ears
from core.mouth import Mouth

print("VIOLET Core initialized.")
